# %%
import requests
import zipfile
import io
import json
from tabulate import tabulate

# %%
api_key = "2e5a7999-a406-4eca-8a54-22a115583e54"
flux_id = "e22e20b5ab01520a013f8411fa327be0"

a = api_key
f = flux_id

url = f"https://diffuseur.datatourisme.fr/webservice/{f}/{a}"

r = requests.get(url)

# --- | The response is a ZIP file | ---
zip_bytes = io.BytesIO(r.content)

with zipfile.ZipFile(zip_bytes) as z:
    print("Files inside ZIP 📁:")

    # --- | Read first JSON inside the ZIP | ---
    filename = z.namelist()[0]
    with z.open(filename) as f:
        json_text = f.read().decode("utf-8")

# --- | Fixed Data | ---
data = json.loads(json_text)

print("JSON Parsed successfully! ✅🎉")
print(type(data))
# Out:
# Files inside ZIP 📁:
# JSON Parsed successfully! ✅🎉
# <class 'dict'>

# %%
# View complete JSON for nth event
n = 21  # Change this to see different events

with zipfile.ZipFile(zip_bytes) as z:
    filename = z.namelist()[n]
    with z.open(filename) as f:
        json_text = f.read().decode("utf-8")
        event_data = json.loads(json_text)

print(f"📄 Complete JSON for Event #{n+1}: {filename}")
print("="*80)
print()
print(json.dumps(event_data, indent=2, ensure_ascii=False))
# Out:
# 📄 Complete JSON for Event #22: objects/0/0a/13-0ac45cce-39cf-3ec5-9196-615a7d7fcb2e.json
# ================================================================================
#
# {
#   "@id": "https://data.datatourisme.fr/13/0ac45cce-39cf-3ec5-9196-615a7d7fcb2e",
#   "dc:identifier": "7083168",
#   "schema:endDate": [
#     "2025-10-04"
#   ],
#   "schema:startDate": [
#     "2025-10-01"
#   ],
#   "@type": [
#     "schema:Event",
#     "schema:SportsEvent",
#     "EntertainmentAndEvent",
#     "PointOfInterest",
#     "SportsCompetition",
#     "SportsEvent"
#   ],
#   "rdfs:comment": {
#     "de": [
#       "Das Ziel des Jump Bost ist es, die besten Reiter der Welt und die hoffnungsvollsten Nachwuchstalente des Reitsports zusammenzubringen?"
#     ],
#     "en": [
#       "Jump Bost aims to bring together the world's best riders and young hopefuls of equestrian sport..."
#     ],
#     "it": [
#       "Jump Bost mira a riunire i migliori cavalieri del mondo e le giovani speranze dello sport equestre?"
#     ],
#     "fr": [
#       "Le Jump Bost a pour objectif de réunir les meilleurs cavaliers mondiaux ainsi que les jeunes espoirs du sport équestre…"
#     ],
#     "nl": [
#       "Jump Bost wil 's werelds beste ruiters en jonge beloften van de paardensport samenbrengen?"
#     ],
#     "es": [
#       "Jump Bost pretende reunir a los mejores jinetes del mundo y a las jóvenes promesas del deporte ecuestre?"
#     ]
#   },
#   "rdfs:label": {
#     "en": [
#       "Jump Bost"
#     ],
#     "fr": [
#       "Jump Bost"
#     ]
#   },
#   "hasBeenCreatedBy": {
#     "@id": "https://data.datatourisme.fr/13/a2137a2a-e8e3-3b50-82a3-f8909ecb88fe",
#     "dc:identifier": "1065",
#     "schema:email": [
#       "emilie@fontainebleau-tourisme.com",
#       "floriane@fontainebleau-tourisme.com",
#       "resp.accueil@fontainebleau-tourisme.com"
#     ],
#     "schema:legalName": "Office de tourisme du Pays de Fontainebleau",
#     "@type": [
#       "schema:Organization",
#       "foaf:Agent",
#       "Agent"
#     ],
#     "foaf:homepage": [
#       "http://www.fontainebleau-tourisme.com/"
#     ]
#   },
#   "hasBeenPublishedBy": [
#     {
#       "@id": "https://data.datatourisme.fr/1db24fc4-b534-39bf-bdaf-152c6f98730e",
#       "schema:legalName": "Seine et Marne Attractivité - source : Apidae Tourisme",
#       "@type": [
#         "schema:Organization",
#         "foaf:Agent",
#         "Agent"
#       ],
#       "foaf:homepage": [
#         "https://www.apidae-tourisme.com/"
#       ]
#     }
#   ],
#   "hasContact": [
#     {
#       "@id": "https://data.datatourisme.fr/89532817-6279-341c-9ee5-2f8f7ab82dba",
#       "schema:email": [
#         "ecurie.bost@wanadoo.fr"
#       ],
#       "schema:telephone": [
#         "+33 1 64 23 42 87"
#       ],
#       "@type": [
#         "foaf:Agent",
#         "Agent"
#       ],
#       "foaf:homepage": [
#         "http://www.grandparquet.com/"
#       ]
#     }
#   ],
#   "hasDescription": [
#     {
#       "@id": "https://data.datatourisme.fr/265e33f3-158e-38ce-911f-1eebd7654274",
#       "@type": [
#         "Description"
#       ],
#       "hasTranslatedProperty": [
#         {
#           "@id": "https://data.datatourisme.fr/071cd649-5a03-30cf-872f-e43a12b0426a",
#           "dc:contributor": [
#             "https://api.deepl.com/v2/translate"
#           ],
#           "rdf:language": [
#             "it"
#           ],
#           "rdf:predicate": [
#             "shortDescription"
#           ]
#         },
#         {
#           "@id": "https://data.datatourisme.fr/b5497dc0-f0b9-34d9-8004-beb106ee7bc1",
#           "dc:contributor": [
#             "https://api.deepl.com/v2/translate"
#           ],
#           "rdf:language": [
#             "nl"
#           ],
#           "rdf:predicate": [
#             "shortDescription"
#           ]
#         },
#         {
#           "@id": "https://data.datatourisme.fr/ed5ac4ca-5b7b-3a5e-8897-80de0768f7b3",
#           "dc:contributor": [
#             "https://api.deepl.com/v2/translate"
#           ],
#           "rdf:language": [
#             "es"
#           ],
#           "rdf:predicate": [
#             "shortDescription"
#           ]
#         },
#         {
#           "@id": "https://data.datatourisme.fr/fad2eb7a-e12f-3fcd-a822-3dc079515026",
#           "dc:contributor": [
#             "https://api.deepl.com/v2/translate"
#           ],
#           "rdf:language": [
#             "de"
#           ],
#           "rdf:predicate": [
#             "shortDescription"
#           ]
#         }
#       ],
#       "shortDescription": {
#         "de": [
#           "Das Ziel des Jump Bost ist es, die besten Reiter der Welt und die hoffnungsvollsten Nachwuchstalente des Reitsports zusammenzubringen?"
#         ],
#         "en": [
#           "Jump Bost aims to bring together the world's best riders and young hopefuls of equestrian sport..."
#         ],
#         "it": [
#           "Jump Bost mira a riunire i migliori cavalieri del mondo e le giovani speranze dello sport equestre?"
#         ],
#         "fr": [
#           "Le Jump Bost a pour objectif de réunir les meilleurs cavaliers mondiaux ainsi que les jeunes espoirs du sport équestre…"
#         ],
#         "nl": [
#           "Jump Bost wil 's werelds beste ruiters en jonge beloften van de paardensport samenbrengen?"
#         ],
#         "es": [
#           "Jump Bost pretende reunir a los mejores jinetes del mundo y a las jóvenes promesas del deporte ecuestre?"
#         ]
#       }
#     }
#   ],
#   "hasTranslatedProperty": [
#     {
#       "@id": "https://data.datatourisme.fr/3fcdf0ac-c059-38c5-9511-138974b3acbc",
#       "dc:contributor": [
#         "https://api.deepl.com/v2/translate"
#       ],
#       "rdf:language": [
#         "de"
#       ],
#       "rdf:predicate": [
#         {
#           "@id": "rdfs:comment"
#         }
#       ]
#     },
#     {
#       "@id": "https://data.datatourisme.fr/6c6c00a5-e690-3f7d-8a19-a62fe4952666",
#       "dc:contributor": [
#         "https://api.deepl.com/v2/translate"
#       ],
#       "rdf:language": [
#         "es"
#       ],
#       "rdf:predicate": [
#         {
#           "@id": "rdfs:comment"
#         }
#       ]
#     },
#     {
#       "@id": "https://data.datatourisme.fr/a6b66fa6-d014-3fca-9ed4-fdf9f830a827",
#       "dc:contributor": [
#         "https://api.deepl.com/v2/translate"
#       ],
#       "rdf:language": [
#         "it"
#       ],
#       "rdf:predicate": [
#         {
#           "@id": "rdfs:comment"
#         }
#       ]
#     },
#     {
#       "@id": "https://data.datatourisme.fr/e230c39a-f1d0-3079-b8bd-9164766b71c7",
#       "dc:contributor": [
#         "https://api.deepl.com/v2/translate"
#       ],
#       "rdf:language": [
#         "nl"
#       ],
#       "rdf:predicate": [
#         {
#           "@id": "rdfs:comment"
#         }
#       ]
#     }
#   ],
#   "isLocatedAt": [
#     {
#       "@id": "https://data.datatourisme.fr/42e38e0d-aa42-37b3-aa90-21bdba95462c",
#       "schema:address": [
#         {
#           "@id": "https://data.datatourisme.fr/ad295802-e6da-3ef8-9b77-b5c3ae951d55",
#           "schema:addressLocality": "Fontainebleau",
#           "schema:postalCode": "77300",
#           "schema:streetAddress": [
#             "Le Grand Parquet",
#             "Route d'Orléans, RN 152"
#           ],
#           "@type": [
#             "schema:PostalAddress",
#             "PostalAddress"
#           ],
#           "hasAddressCity": {
#             "@id": "kb:77186",
#             "@type": [
#               "City"
#             ],
#             "rdfs:label": {
#               "de": [
#                 "Fontainebleau"
#               ],
#               "pt": [
#                 "Fontainebleau"
#               ],
#               "en": [
#                 "Fontainebleau"
#               ],
#               "it": [
#                 "Fontainebleau"
#               ],
#               "fr": [
#                 "Fontainebleau"
#               ],
#               "nl": [
#                 "Fontainebleau"
#               ],
#               "es": [
#                 "Fontainebleau"
#               ]
#             },
#             "insee": "77186",
#             "isPartOfDepartment": {
#               "@id": "kb:France1177",
#               "@type": [
#                 "Department"
#               ],
#               "rdfs:label": {
#                 "de": [
#                   "Seine-et-Marne"
#                 ],
#                 "pt": [
#                   "Seine-et-Marne"
#                 ],
#                 "en": [
#                   "Seine-et-Marne"
#                 ],
#                 "it": [
#                   "Seine-et-Marne"
#                 ],
#                 "fr": [
#                   "Seine-et-Marne"
#                 ],
#                 "nl": [
#                   "Seine-et-Marne"
#                 ],
#                 "es": [
#                   "Seine-et-Marne"
#                 ]
#               },
#               "insee": "77",
#               "isPartOfRegion": {
#                 "@id": "kb:France11",
#                 "@type": [
#                   "Region"
#                 ],
#                 "rdfs:label": {
#                   "de": [
#                     "Île-de-France"
#                   ],
#                   "pt": [
#                     "Île-de-France"
#                   ],
#                   "en": [
#                     "Île-de-France"
#                   ],
#                   "it": [
#                     "Île-de-France"
#                   ],
#                   "fr": [
#                     "Île-de-France"
#                   ],
#                   "nl": [
#                     "Île-de-France"
#                   ],
#                   "es": [
#                     "Île-de-France"
#                   ]
#                 },
#                 "insee": "11",
#                 "isPartOfCountry": {
#                   "@id": "kb:France",
#                   "@type": [
#                     "schema:Country"
#                   ],
#                   "rdfs:label": {
#                     "de": [
#                       "France",
#                       "Frankreich"
#                     ],
#                     "pt": [
#                       "França",
#                       "France"
#                     ],
#                     "en": [
#                       "France"
#                     ],
#                     "it": [
#                       "France",
#                       "Francia"
#                     ],
#                     "fr": [
#                       "France"
#                     ],
#                     "nl": [
#                       "France",
#                       "Frankrijk"
#                     ],
#                     "es": [
#                       "France",
#                       "Francia"
#                     ]
#                   }
#                 }
#               }
#             }
#           }
#         }
#       ],
#       "schema:geo": {
#         "@id": "https://data.datatourisme.fr/c112ab94-076b-313e-ab08-2fca40874174",
#         "schema:latitude": "48.392257",
#         "schema:longitude": "2.672708",
#         "@type": [
#           "schema:GeoCoordinates"
#         ]
#       },
#       "schema:openingHoursSpecification": [
#         {
#           "@id": "https://data.datatourisme.fr/03855ff1-8f03-311e-998b-2c595c01dfcc",
#           "schema:validFrom": "2025-10-01T00:00:00",
#           "schema:validThrough": "2025-10-04T23:59:59",
#           "@type": [
#             "schema:OpeningHoursSpecification"
#           ]
#         }
#       ],
#       "@type": [
#         "schema:Place",
#         "Place"
#       ]
#     }
#   ],
#   "isOwnedBy": [
#     {
#       "@id": "https://data.datatourisme.fr/7245a75e-5f44-3763-8c19-6eb88c1821b2",
#       "schema:email": [
#         "emilie@fontainebleau-tourisme.com",
#         "floriane@fontainebleau-tourisme.com",
#         "resp.accueil@fontainebleau-tourisme.com"
#       ],
#       "schema:legalName": "Office de tourisme du Pays de Fontainebleau",
#       "@type": [
#         "schema:Organization",
#         "foaf:Agent",
#         "Agent"
#       ],
#       "foaf:homepage": [
#         "http://www.fontainebleau-tourisme.com/"
#       ]
#     }
#   ],
#   "lastUpdate": "2025-12-19",
#   "lastUpdateDatatourisme": "2025-12-20T06:50:20.068Z",
#   "takesPlaceAt": [
#     {
#       "@id": "https://data.datatourisme.fr/125186c6-bb4a-3014-9305-f4cdced7a259",
#       "@type": [
#         "Period"
#       ],
#       "endDate": "2025-10-04",
#       "startDate": "2025-10-01"
#     }
#   ]
# }

# %%
# --- | Inspecting the Structure of One Event to See What's Actually There | ---

with zipfile.ZipFile(zip_bytes) as z:
    filename = z.namelist()[0]
    with z.open(filename) as f:
        json_text = f.read().decode("utf-8")
        sample_event = json.loads(json_text)

# --- | Print the keys to see what's available | ---
print("Available keys in the event:")
print(json.dumps(list(sample_event.keys()), indent=2))
# Out:
# Available keys in the event:
# [
#   "@id",
#   "dc:identifier",
#   "schema:endDate",
#   "schema:startDate",
#   "@type",
#   "rdfs:comment",
#   "rdfs:label",
#   "hasBeenCreatedBy",
#   "hasBeenPublishedBy",
#   "hasContact",
#   "hasDescription",
#   "hasTranslatedProperty",
#   "isLocatedAt",
#   "isOwnedBy",
#   "lastUpdate",
#   "lastUpdateDatatourisme",
#   "offers",
#   "takesPlaceAt"
# ]

# %%
# use = int(input("Enter a Number Between 1 and 2: "))
use = 2
if use == 1:
    # Let's look at a few potentially relevant fields
    if "rdfs:label" in sample_event:
        print("Label:", sample_event["rdfs:label"])

    if "schema:location" in sample_event:
        print("\nLocation:", sample_event["schema:location"])

    if "hasBeenPublishedBy" in sample_event:
        print("\nPublished by:", sample_event["hasBeenPublishedBy"])

    if "isLocatedAt" in sample_event:
        print("\nIs located at:", sample_event["isLocatedAt"])

    # Print dates
    for key in sample_event.keys():
        if "date" in key.lower() or "Date" in key:
            print(f"\n{key}:", sample_event[key])


elif use == 2:
    # Let's look at a few potentially relevant fields
    if "rdfs:label" in sample_event:
        print("📝 **Label:**", sample_event["rdfs:label"].get('fr', ['N/A'])[0])

    if "schema:location" in sample_event:
        print("\n📍 **Location:**", sample_event["schema:location"])

    if "hasBeenPublishedBy" in sample_event:
        print("\n🏢 **Published by:**")
        publisher = sample_event["hasBeenPublishedBy"][0]
        print(f"  - Organization: {publisher.get('schema:legalName', 'N/A')}")
        print(f"  - Website: {publisher.get('foaf:homepage', ['N/A'])[0]}")

    if "isLocatedAt" in sample_event:
        print("\n📍 **Is located at:**")
        location = sample_event["isLocatedAt"][0]
        address = location.get('schema:address', [{}])[0]
        print(f"  - Address: {', '.join(address.get('schema:streetAddress', ['N/A']))}")
        print(f"  - City: {address.get('schema:addressLocality', 'N/A')}")
        print(f"  - Postal Code: {address.get('schema:postalCode', 'N/A')}")
        print(f"  - Region: {address.get('isPartOfRegion', {}).get('rdfs:label', {}).get('en', 'N/A')}")
        print(f"  - Country: {address.get('isPartOfCountry', {}).get('rdfs:label', {}).get('en', 'N/A')}")
    # Print dates
    print("\n📅 **Dates:**")
    for key in sample_event.keys():
        if "date" in key.lower() or "Date" in key:
            print(f"  - {key}: {sample_event[key]}")

else :
  print("Invalid Input")
# Out:
# 📝 **Label:** Valse avec W* - Marc Lacourt
#
# 🏢 **Published by:**
#   - Organization: Apidae Tourisme Scic SA - source : Apidae Tourisme
#   - Website: https://www.apidae-tourisme.com/
#
# 📍 **Is located at:**
#   - Address: 123 rue de Saint Germain, Théatre du Cormier
#   - City: Cormeilles-en-Parisis
#   - Postal Code: 95240
#   - Region: N/A
#   - Country: N/A
#
# 📅 **Dates:**
#   - schema:endDate: ['2025-01-27']
#   - schema:startDate: ['2025-01-27']
#   - lastUpdate: 2025-06-10
#   - lastUpdateDatatourisme: 2025-10-28T09:01:14.776Z

# %%
# Specify which event you want to see (nth event, starting from 0)
n = 0 # Change this to see different events (0 for first, 1 for second, etc.)

# Get the nth event from the ZIP
with zipfile.ZipFile(zip_bytes) as z:
    filename = z.namelist()[n]
    with z.open(filename) as f:
        json_text = f.read().decode("utf-8")
        event_data = json.loads(json_text)

print(f"📍 EVENT #{n+1}: {filename}")
print("="*80)
print()

# Function to flatten nested data for display
def format_value(value, indent=0):
    """Format values for better readability"""
    if isinstance(value, dict):
        if 'fr' in value:
            return value['fr'][0] if isinstance(value['fr'], list) else value['fr']
        return json.dumps(value, indent=2, ensure_ascii=False)
    elif isinstance(value, list):
        if len(value) > 0 and isinstance(value[0], dict):
            return json.dumps(value, indent=2, ensure_ascii=False)
        return ', '.join(str(v) for v in value)
    return str(value)

# Prepare main event details
main_details = []
for key, value in event_data.items():
    if key not in ['isLocatedAt', 'hasContact', 'hasDescription', 'takesPlaceAt', 'hasTranslatedProperty']:
        formatted_value = format_value(value)
        # Truncate very long values
        if len(formatted_value) > 100:
            formatted_value = formatted_value[:100] + "..."
        main_details.append([key, formatted_value])

print("📋 MAIN DETAILS:")
print(tabulate(main_details, headers=['Field', 'Value'], tablefmt='grid', maxcolwidths=[30, 80]))
print()

# Location details
if event_data.get("isLocatedAt"):
    location_data = event_data["isLocatedAt"][0]
    location_details = []

    if location_data.get("schema:address"):
        address = location_data["schema:address"][0]
        location_details.append(["City", address.get("schema:addressLocality", "N/A")])
        location_details.append(["Postal Code", address.get("schema:postalCode", "N/A")])
        location_details.append(["Street", ', '.join(address.get("schema:streetAddress", ["N/A"]))])

    if location_data.get("schema:geo"):
        geo = location_data["schema:geo"]
        location_details.append(["Latitude", geo.get("schema:latitude", "N/A")])
        location_details.append(["Longitude", geo.get("schema:longitude", "N/A")])

    print("📍 LOCATION:")
    print(tabulate(location_details, headers=['Field', 'Value'], tablefmt='grid'))
    print()

# Contact details
if event_data.get("hasContact"):
    contact_data = event_data["hasContact"][0]
    contact_details = []

    for key, value in contact_data.items():
        if not key.startswith('@'):
            formatted_value = format_value(value)
            if len(formatted_value) > 100:
                formatted_value = formatted_value[:100] + "..."
            contact_details.append([key, formatted_value])

    if contact_details:
        print("📞 CONTACT:")
        print(tabulate(contact_details, headers=['Field', 'Value'], tablefmt='grid', maxcolwidths=[30, 80]))
        print()

# Description
if event_data.get("hasDescription"):
    desc_data = event_data["hasDescription"][0]
    print("📝 DESCRIPTION:")
    if desc_data.get("dc:description"):
        desc = desc_data["dc:description"].get("fr", ["N/A"])[0]
        print(f"{desc[:500]}..." if len(desc) > 500 else desc)
    print()

# Schedule/Opening hours
if event_data.get("isLocatedAt") and event_data["isLocatedAt"][0].get("schema:openingHoursSpecification"):
    schedule = event_data["isLocatedAt"][0]["schema:openingHoursSpecification"]
    schedule_details = []

    for slot in schedule[:5]:  # Show first 5 time slots
        schedule_details.append([
            slot.get("schema:validFrom", "N/A"),
            slot.get("schema:opens", "N/A"),
            slot.get("schema:closes", "N/A")
        ])

    if schedule_details:
        print("🕐 SCHEDULE:")
        print(tabulate(schedule_details, headers=['Date', 'Opens', 'Closes'], tablefmt='grid'))
        print()
# Out:
# 📍 EVENT #1: objects/0/00/13-0050d2fd-ebec-3fd0-a5b4-f88c9bf96285.json
# ================================================================================
#
# 📋 MAIN DETAILS:
# +------------------------+------------------------------------------------------------------------------+
# | Field                  | Value                                                                        |
# +========================+==============================================================================+
# | @id                    | https://data.datatourisme.fr/13/0050d2fd-ebec-3fd0-a5b4-f88c9bf96285         |
# +------------------------+------------------------------------------------------------------------------+
# | dc:identifier          | 7391218                                                                      |
# +------------------------+------------------------------------------------------------------------------+
# | schema:endDate         | 2025-01-27                                                                   |
# +------------------------+------------------------------------------------------------------------------+
# | schema:startDate       | 2025-01-27                                                                   |
# +------------------------+------------------------------------------------------------------------------+
# | @type                  | schema:Event, schema:TheaterEvent, CulturalEvent, EntertainmentAndEvent,     |
# |                        | PointOfInterest, ShowEvent,...                                               |
# +------------------------+------------------------------------------------------------------------------+
# | rdfs:comment           | De la moquette, un frigo, des cowboys, des monstres, et un récit sens dessus |
# |                        | dessous… Le chorégraphe...                                                   |
# +------------------------+------------------------------------------------------------------------------+
# | rdfs:label             | Valse avec W* - Marc Lacourt                                                 |
# +------------------------+------------------------------------------------------------------------------+
# | hasBeenCreatedBy       | {   "@id":                                                                   |
# |                        | "https://data.datatourisme.fr/13/766d856e-f1a6-302f-93d8-94415e6bfa0e",      |
# |                        | "dc:identifier"...                                                           |
# +------------------------+------------------------------------------------------------------------------+
# | hasBeenPublishedBy     | [   {     "@id":                                                             |
# |                        | "https://data.datatourisme.fr/8a9feb4b-2cbd-3d2c-b507-bd6c6776b23b",         |
# |                        | "schema:le...                                                                |
# +------------------------+------------------------------------------------------------------------------+
# | isOwnedBy              | [   {     "@id":                                                             |
# |                        | "https://data.datatourisme.fr/fa659dd9-d85a-35f9-ae7c-548179e73a31",         |
# |                        | "schema:em...                                                                |
# +------------------------+------------------------------------------------------------------------------+
# | lastUpdate             | 2025-06-10                                                                   |
# +------------------------+------------------------------------------------------------------------------+
# | lastUpdateDatatourisme | 2025-10-28T09:01:14.776Z                                                     |
# +------------------------+------------------------------------------------------------------------------+
# | offers                 | [   {     "@id":                                                             |
# |                        | "https://data.datatourisme.fr/acf714fe-6220-350a-9ab7-50e6296ccc40",         |
# |                        | "schema:pr...                                                                |
# +------------------------+------------------------------------------------------------------------------+
#
# 📍 LOCATION:
# +-------------+----------------------------------------------+
# | Field       | Value                                        |
# +=============+==============================================+
# | City        | Cormeilles-en-Parisis                        |
# +-------------+----------------------------------------------+
# | Postal Code | 95240                                        |
# +-------------+----------------------------------------------+
# | Street      | 123 rue de Saint Germain, Théatre du Cormier |
# +-------------+----------------------------------------------+
# | Latitude    | 48.955656                                    |
# +-------------+----------------------------------------------+
# | Longitude   | 2.186522                                     |
# +-------------+----------------------------------------------+
#
# 📞 CONTACT:
# +------------------+-------------------------------+
# | Field            | Value                         |
# +==================+===============================+
# | schema:email     | culture@ville-cormeilles95.fr |
# +------------------+-------------------------------+
# | schema:telephone | +33 1 34 50 47 65             |
# +------------------+-------------------------------+
#
# 📝 DESCRIPTION:
#
# 🕐 SCHEDULE:
# +---------------------+----------+----------+
# | Date                | Opens    | Closes   |
# +=====================+==========+==========+
# | 2025-01-27T00:00:00 | 20:30:00 | N/A      |
# +---------------------+----------+----------+

# %%
# Extract first n events with selected fields
events = []
n = 10
# Get first 10 JSON files from the ZIP
for filename in z.namelist()[:n]:
    with zipfile.ZipFile(zip_bytes) as z:
        with z.open(filename) as f:
            json_text = f.read().decode("utf-8")
            event_data = json.loads(json_text)

            # Extract label
            label = event_data.get("rdfs:label", {}).get("fr", ["N/A"])[0]

            # Extract location from isLocatedAt
            location = "N/A"
            if event_data.get("isLocatedAt"):
                address = event_data["isLocatedAt"][0].get("schema:address", [{}])[0]
                location = address.get("schema:addressLocality", "N/A")
                location += ", " + address.get("schema:postalCode", "N/A")

            # Extract dates
            start_date = event_data.get("schema:startDate", ["N/A"])[0]
            end_date = event_data.get("schema:endDate", ["N/A"])[0]

            event = {
                "label": label,
                "location": location,
                "start_date": start_date,
                "end_date": end_date
            }
            events.append(event)

# Display the events
for i, event in enumerate(events, 1):
    print(f"{i}. {event['label']}")
    print(f"   Location: {event['location']}")
    print(f"   Start: {event['start_date']}")
    print(f"   End: {event['end_date']}")
    print()
# Out:
# 1. Valse avec W* - Marc Lacourt
#    Location: Cormeilles-en-Parisis, 95240
#    Start: 2025-01-27
#    End: 2025-01-27
#
# 2. Marché des 4-Routes de Drancy
#    Location: Drancy, 93700
#    Start: 2025-01-01
#    End: 2025-12-31
#
# 3. Les balades passerelles
#    Location: Pantin, 93695
#    Start: 2025-01-01
#    End: 2025-12-31
#
# 4. Chasse, Pêche, Nature & Vénerie en fête
#    Location: Fontainebleau, 77300
#    Start: 2025-05-30
#    End: 2025-05-31
#
# 5. Philtre d'Amour (Ensemble Virêvolte)
#    Location: Cormeilles-en-Parisis, 95240
#    Start: 2025-03-10
#    End: 2025-03-10
#
# 6. Marché Outrebon
#    Location: Villemomble, 93250
#    Start: 2025-01-01
#    End: 2025-12-31
#
# 7. L’École de Paris
#    Location: Paris, 75018
#    Start: 2025-10-17
#    End: 2025-02-15
#
# 8. Le marché de l'Axe Majeur / Horloge
#    Location: Cergy, 95000
#    Start: 2025-01-01
#    End: 2025-12-31
#
# 9. Isha - Sarah Lenka
#    Location: Cormeilles-en-Parisis, 95240
#    Start: 2025-04-09
#    End: 2025-04-09
#
# 10. La Voie de l'Écuyère
#    Location: Versailles, 78000
#    Start: 2025-09-20
#    End: 2025-12-31

# %%
# view = int(input("Enter a Number Between 1 and 3: "))
view = 2

if view == 1:
  import pandas as pd

  # Create DataFrame from events list
  df = pd.DataFrame(events)

  # Display with better column names
  df.columns = ['Event Name', 'Location', 'Start Date', 'End Date']
  df.index = range(1, len(df) + 1)

  display(df)


elif view == 2:
  # Create table
  table_data = []
  for i, event in enumerate(events, 1):
      table_data.append([
          i,
          event['label'],
          event['location'],
          event['start_date'],
          event['end_date']
      ])

  print(tabulate(table_data,
                headers=['#', 'Event Name', 'Location', 'Start Date', 'End Date'],
                tablefmt='grid'))


elif view == 3:
  # Print header
  print(f"{'#':<4} {'Event Name':<50} {'Location':<20} {'Start Date':<12} {'End Date':<12}")
  print("-" * 100)

  # Print rows
  for i, event in enumerate(events, 1):
      label = event['label'][:47] + '...' if len(event['label']) > 50 else event['label']
      location = event['location'][:17] + '...' if len(event['location']) > 20 else event['location']

      print(f"{i:<4} {label:<50} {location:<20} {event['start_date']:<12} {event['end_date']:<12}")


else :
  print("Invalid Input")
# Out:
# +-----+-----------------------------------------+------------------------------+--------------+------------+
# |   # | Event Name                              | Location                     | Start Date   | End Date   |
# +=====+=========================================+==============================+==============+============+
# |   1 | Valse avec W* - Marc Lacourt            | Cormeilles-en-Parisis, 95240 | 2025-01-27   | 2025-01-27 |
# +-----+-----------------------------------------+------------------------------+--------------+------------+
# |   2 | Marché des 4-Routes de Drancy           | Drancy, 93700                | 2025-01-01   | 2025-12-31 |
# +-----+-----------------------------------------+------------------------------+--------------+------------+
# |   3 | Les balades passerelles                 | Pantin, 93695                | 2025-01-01   | 2025-12-31 |
# +-----+-----------------------------------------+------------------------------+--------------+------------+
# |   4 | Chasse, Pêche, Nature & Vénerie en fête | Fontainebleau, 77300         | 2025-05-30   | 2025-05-31 |
# +-----+-----------------------------------------+------------------------------+--------------+------------+
# |   5 | Philtre d'Amour (Ensemble Virêvolte)    | Cormeilles-en-Parisis, 95240 | 2025-03-10   | 2025-03-10 |
# +-----+-----------------------------------------+------------------------------+--------------+------------+
# |   6 | Marché Outrebon                         | Villemomble, 93250           | 2025-01-01   | 2025-12-31 |
# +-----+-----------------------------------------+------------------------------+--------------+------------+
# |   7 | L’École de Paris                        | Paris, 75018                 | 2025-10-17   | 2025-02-15 |
# +-----+-----------------------------------------+------------------------------+--------------+------------+
# |   8 | Le marché de l'Axe Majeur / Horloge     | Cergy, 95000                 | 2025-01-01   | 2025-12-31 |
# +-----+-----------------------------------------+------------------------------+--------------+------------+
# |   9 | Isha - Sarah Lenka                      | Cormeilles-en-Parisis, 95240 | 2025-04-09   | 2025-04-09 |
# +-----+-----------------------------------------+------------------------------+--------------+------------+
# |  10 | La Voie de l'Écuyère                    | Versailles, 78000            | 2025-09-20   | 2025-12-31 |
# +-----+-----------------------------------------+------------------------------+--------------+------------+

# %%
# Extract first n events with MORE selected fields including region and department
events = []
n = 4
# Get first 10 JSON files from the ZIP
for filename in z.namelist()[:n]:
    with zipfile.ZipFile(zip_bytes) as z:
        with z.open(filename) as f:
            json_text = f.read().decode("utf-8")
            event_data = json.loads(json_text)

            # Extract label
            label = event_data.get("rdfs:label", {}).get("fr", ["N/A"])[0]

            # Extract location details from isLocatedAt
            location = "N/A"
            postal_code = "N/A"
            department = "N/A"
            region = "N/A"
            latitude = "N/A"
            longitude = "N/A"

            if event_data.get("isLocatedAt"):
                location_data = event_data["isLocatedAt"][0]

                # Get address
                if location_data.get("schema:address"):
                    address = location_data["schema:address"][0]
                    location = address.get("schema:addressLocality", "N/A")
                    postal_code = address.get("schema:postalCode", "N/A")

                    # Get department and region from nested structure
                    if address.get("hasAddressCity"):
                        city_data = address["hasAddressCity"]

                        if city_data.get("isPartOfDepartment"):
                            dept_data = city_data["isPartOfDepartment"]
                            department = dept_data.get("rdfs:label", {}).get("fr", "N/A")

                            if dept_data.get("isPartOfRegion"):
                                region_data = dept_data["isPartOfRegion"]
                                region = region_data.get("rdfs:label", {}).get("fr", "N/A")

                # Get coordinates
                if location_data.get("schema:geo"):
                    geo = location_data["schema:geo"]
                    latitude = geo.get("schema:latitude", "N/A")
                    longitude = geo.get("schema:longitude", "N/A")

            # Extract dates
            start_date = event_data.get("schema:startDate", ["N/A"])[0]
            end_date = event_data.get("schema:endDate", ["N/A"])[0]

            # Extract description
            description = "N/A"
            if event_data.get("hasDescription"):
                desc_data = event_data["hasDescription"][0]
                if desc_data.get("dc:description"):
                    description = desc_data["dc:description"].get("fr", ["N/A"])[0]
                    # Truncate long descriptions
                    if len(description) > 150:
                        description = description[:150] + "..."

            event = {
                "label": label,
                "location": location,
                "postal_code": postal_code,
                "department": department,
                "region": region,
                "start_date": start_date,
                "end_date": end_date,
                "latitude": latitude,
                "longitude": longitude,
                "description": description
            }
            events.append(event)

# Display with pandas for better formatting
import pandas as pd

df = pd.DataFrame(events)
df.index = range(1, len(df) + 1)

# Display with better column names
df.columns = ['Event Name', 'City', 'Postal Code', 'Department', 'Region',
              'Start Date', 'End Date', 'Latitude', 'Longitude', 'Description']

display(df)
# Out:
#                                 Event Name                   City Postal Code  \
# 1             Valse avec W* - Marc Lacourt  Cormeilles-en-Parisis       95240
# 2            Marché des 4-Routes de Drancy                 Drancy       93700
# 3                  Les balades passerelles                 Pantin       93695
# 4  Chasse, Pêche, Nature & Vénerie en fête          Fontainebleau       77300
#
#             Department           Region  Start Date    End Date   Latitude  \
# 1         [Val-d'Oise]  [Île-de-France]  2025-01-27  2025-01-27  48.955656
# 2  [Seine-Saint-Denis]  [Île-de-France]  2025-01-01  2025-12-31  48.919432
# 3  [Seine-Saint-Denis]  [Île-de-France]  2025-01-01  2025-12-31  48.891964
# 4     [Seine-et-Marne]  [Île-de-France]  2025-05-30  2025-05-31  48.392257
#
#   Longitude Description
# 1  2.186522         N/A
# 2  2.450536         N/A
# 3  2.408908         N/A
# 4  2.672708         N/A

# %% [markdown]
# _________________

# %%
import requests
import zipfile
import io
import json
from collections import Counter

# Your API credentials
api_key = "2e5a7999-a406-4eca-8a54-22a115583e54"
flux_id = "e22e20b5ab01520a013f8411fa327be0"

url = f"https://diffuseur.datatourisme.fr/webservice/{flux_id}/{api_key}"
r = requests.get(url)
zip_bytes = io.BytesIO(r.content)

# Explore event types and categories
event_types = []
categories = []
locations = []

print("🔍 Analyzing first 50 events to understand data structure...\n")

with zipfile.ZipFile(zip_bytes) as z:
    for i, filename in enumerate(z.namelist()[:50]):
        with z.open(filename) as f:
            json_text = f.read().decode("utf-8")
            event_data = json.loads(json_text)

            # Collect event types
            if "@type" in event_data:
                event_types.extend(event_data["@type"])

            # Collect location info
            if event_data.get("isLocatedAt"):
                location_data = event_data["isLocatedAt"][0]
                if location_data.get("schema:address"):
                    address = location_data["schema:address"][0]
                    city = address.get("schema:addressLocality", "")
                    if city:
                        locations.append(city)

# Count occurrences
type_counts = Counter(event_types)
location_counts = Counter(locations)

print("📊 EVENT TYPES FOUND:")
print("=" * 60)
for event_type, count in type_counts.most_common(20):
    print(f"  {event_type}: {count}")

print("\n📍 TOP CITIES FOUND:")
print("=" * 60)
for city, count in location_counts.most_common(15):
    print(f"  {city}: {count}")

print("\n💡 Sample event structure keys:")
print("=" * 60)
with zipfile.ZipFile(zip_bytes) as z:
    with z.open(z.namelist()[0]) as f:
        sample = json.loads(f.read().decode("utf-8"))
        for key in sample.keys():
            print(f"  - {key}")
# Out:
# 🔍 Analyzing first 50 events to understand data structure...
#
# 📊 EVENT TYPES FOUND:
# ============================================================
#   schema:Event: 50
#   EntertainmentAndEvent: 50
#   PointOfInterest: 50
#   CulturalEvent: 24
#   schema:SaleEvent: 21
#   SaleEvent: 21
#   Market: 18
#   schema:ExhibitionEvent: 10
#   Exhibition: 10
#   schema:TheaterEvent: 5
#   ShowEvent: 5
#   TheaterEvent: 5
#   SportsEvent: 5
#   schema:SportsEvent: 3
#   schema:MusicEvent: 3
#   Concert: 3
#   schema:Product: 2
#   Product: 2
#   Visit: 2
#   SportsCompetition: 2
#
# 📍 TOP CITIES FOUND:
# ============================================================
#   Paris: 6
#   Cormeilles-en-Parisis: 5
#   Fontainebleau: 3
#   Paris 16e Arrondissement: 2
#   Paris 15e Arrondissement: 2
#   Wissous: 2
#   Saint-Rémy-lès-Chevreuse: 2
#   Drancy: 1
#   Pantin: 1
#   Villemomble: 1
#   Cergy: 1
#   Versailles: 1
#   Jouy-en-Josas: 1
#   Igny: 1
#   Nogent-sur-Marne: 1
#
# 💡 Sample event structure keys:
# ============================================================
#   - @id
#   - dc:identifier
#   - schema:endDate
#   - schema:startDate
#   - @type
#   - rdfs:comment
#   - rdfs:label
#   - hasBeenCreatedBy
#   - hasBeenPublishedBy
#   - hasContact
#   - hasDescription
#   - hasTranslatedProperty
#   - isLocatedAt
#   - isOwnedBy
#   - lastUpdate
#   - lastUpdateDatatourisme
#   - offers
#   - takesPlaceAt

# %%
import requests
import zipfile
import io
import json
from datetime import datetime
from tabulate import tabulate

# API credentials
api_key = "2e5a7999-a406-4eca-8a54-22a115583e54"
flux_id = "e22e20b5ab01520a013f8411fa327be0"

# Industry mapping - maps event types to industries
INDUSTRY_MAPPING = {
    'Market': 'Retail/Food',
    'SaleEvent': 'Retail',
    'schema:SaleEvent': 'Retail',
    'Concert': 'Entertainment',
    'schema:MusicEvent': 'Entertainment',
    'TheaterEvent': 'Entertainment',
    'schema:TheaterEvent': 'Entertainment',
    'Exhibition': 'Arts/Culture',
    'schema:ExhibitionEvent': 'Arts/Culture',
    'CulturalEvent': 'Arts/Culture',
    'SportsEvent': 'Sports/Fitness',
    'schema:SportsEvent': 'Sports/Fitness',
    'SportsCompetition': 'Sports/Fitness',
    'Visit': 'Tourism',
    'ShowEvent': 'Entertainment'
}

# Campaign sector impact rules
IMPACT_RULES = {
    'food': {
        'positive': ['Retail/Food', 'Entertainment', 'Tourism'],
        'negative': ['Sports/Fitness'],
        'neutral': ['Arts/Culture', 'Retail']
    },
    'restaurant': {
        'positive': ['Entertainment', 'Tourism', 'Arts/Culture'],
        'negative': ['Retail/Food'],
        'neutral': ['Sports/Fitness', 'Retail']
    },
    'retail': {
        'positive': ['Tourism', 'Entertainment', 'Arts/Culture'],
        'negative': ['Retail', 'Retail/Food'],
        'neutral': ['Sports/Fitness']
    },
    'fitness': {
        'positive': ['Sports/Fitness'],
        'negative': ['Retail/Food'],
        'neutral': ['Entertainment', 'Tourism', 'Arts/Culture', 'Retail']
    },
    'entertainment': {
        'positive': ['Arts/Culture', 'Tourism'],
        'negative': ['Entertainment'],
        'neutral': ['Retail', 'Sports/Fitness', 'Retail/Food']
    },
    'healthcare': {
        'positive': ['Sports/Fitness'],
        'negative': ['Entertainment', 'Retail/Food'],
        'neutral': ['Tourism', 'Arts/Culture', 'Retail']
    },
    'tourism': {
        'positive': ['Arts/Culture', 'Entertainment', 'Tourism'],
        'negative': [],
        'neutral': ['Retail', 'Sports/Fitness', 'Retail/Food']
    },
    'education': {
        'positive': ['Arts/Culture'],
        'negative': ['Entertainment'],
        'neutral': ['Tourism', 'Retail', 'Sports/Fitness', 'Retail/Food']
    }
}

def safe_extract_list_value(data, default=""):
    """Safely extract value from list or dict"""
    if isinstance(data, list) and len(data) > 0:
        return data[0]
    elif isinstance(data, str):
        return data
    return default

def safe_extract_label(label_data):
    """Safely extract French label from various formats"""
    try:
        if isinstance(label_data, dict):
            fr_data = label_data.get("fr", "N/A")
            if isinstance(fr_data, list) and len(fr_data) > 0:
                return fr_data[0]
            elif isinstance(fr_data, str):
                return fr_data
        return "N/A"
    except:
        return "N/A"

def get_event_industry(event_types):
    """Determine the industry of an event based on its types"""
    if not isinstance(event_types, list):
        return 'General'

    for event_type in event_types:
        if event_type in INDUSTRY_MAPPING:
            return INDUSTRY_MAPPING[event_type]
    return 'General'

def assess_impact(event_industry, campaign_sector):
    """Assess the impact of an event on a campaign"""
    sector_rules = IMPACT_RULES.get(campaign_sector.lower(), {})

    if event_industry in sector_rules.get('positive', []):
        return 'Positive', 'Attracts relevant audience'
    elif event_industry in sector_rules.get('negative', []):
        return 'Negative', 'Competing or conflicting'
    else:
        return 'Neutral', 'Minimal direct impact'

def analyze_campaign(target_date, target_city, campaign_sector):
    """Main function to analyze campaign impact"""

    print(f"\n{'='*80}")
    print(f"📋 CAMPAIGN IMPACT ANALYSIS")
    print(f"{'='*80}")
    print(f"📅 Date: {target_date}")
    print(f"📍 City: {target_city}")
    print(f"🎯 Sector: {campaign_sector.upper()}")
    print(f"{'='*80}\n")

    # Fetch data
    print("⏳ Fetching event data...")
    try:
        url = f"https://diffuseur.datatourisme.fr/webservice/{flux_id}/{api_key}"
        r = requests.get(url, timeout=30)
        zip_bytes = io.BytesIO(r.content)
    except Exception as e:
        print(f"❌ Error fetching data: {e}")
        return

    # Find matching events
    matching_events = []
    processed_count = 0

    try:
        with zipfile.ZipFile(zip_bytes) as z:
            total_files = len(z.namelist())
            print(f"📦 Processing {total_files} events...")

            for filename in z.namelist():
                try:
                    with z.open(filename) as f:
                        json_text = f.read().decode("utf-8")
                        event_data = json.loads(json_text)
                        processed_count += 1

                        # Progress indicator every 100 events
                        if processed_count % 100 == 0:
                            print(f"   Processed {processed_count}/{total_files} events...")

                        # Extract and validate dates
                        start_date_raw = event_data.get("schema:startDate")
                        end_date_raw = event_data.get("schema:endDate")

                        start_date = safe_extract_list_value(start_date_raw)
                        end_date = safe_extract_list_value(end_date_raw)

                        # Skip if no valid dates
                        if not start_date or not end_date:
                            continue

                        # Check date match
                        if target_date >= start_date and target_date <= end_date:
                            # Check city match
                            if event_data.get("isLocatedAt"):
                                location_data = event_data["isLocatedAt"][0] if isinstance(event_data["isLocatedAt"], list) else event_data["isLocatedAt"]

                                if location_data.get("schema:address"):
                                    address_data = location_data["schema:address"]
                                    address = address_data[0] if isinstance(address_data, list) else address_data
                                    city = address.get("schema:addressLocality", "")

                                    if target_city.lower() in city.lower():
                                        # Extract event details
                                        event_name = safe_extract_label(event_data.get("rdfs:label", {}))
                                        event_types = event_data.get("@type", [])
                                        industry = get_event_industry(event_types)
                                        impact, reason = assess_impact(industry, campaign_sector)

                                        matching_events.append({
                                            'name': event_name,
                                            'date': start_date,
                                            'industry': industry,
                                            'impact': impact,
                                            'reason': reason,
                                            'location': city
                                        })
                except Exception as e:
                    # Skip problematic events silently
                    continue

    except Exception as e:
        print(f"❌ Error processing data: {e}")
        return

    print(f"\n✅ Found {len(matching_events)} events matching your criteria\n")

    if not matching_events:
        print("❌ No events found for the specified date and city.")
        print("\n💡 Tips:")
        print("   - Try a different date (e.g., 2025-03-10, 2025-05-30)")
        print("   - Check the city name spelling")
        print("   - Try these cities: Paris, Cormeilles-en-Parisis, Fontainebleau, Versailles")
        return

    # Prepare table data
    table_data = []
    positive_count = 0
    negative_count = 0
    neutral_count = 0

    for i, event in enumerate(matching_events, 1):
        # Count impacts
        if event['impact'] == 'Positive':
            positive_count += 1
            impact_icon = '✅'
        elif event['impact'] == 'Negative':
            negative_count += 1
            impact_icon = '⚠️'
        else:
            neutral_count += 1
            impact_icon = '➖'

        table_data.append([
            i,
            event['name'][:40] + '...' if len(event['name']) > 40 else event['name'],
            event['industry'],
            f"{impact_icon} {event['impact']}",
            event['reason']
        ])

    # Display results
    print(tabulate(
        table_data,
        headers=['Sr.No.', 'Event Name', 'Industry', 'Impact', 'Reason'],
        tablefmt='grid',
        maxcolwidths=[6, 40, 15, 15, 25]
    ))

    # Summary
    print(f"\n{'='*80}")
    print("📊 IMPACT SUMMARY")
    print(f"{'='*80}")
    print(f"✅ Positive Impact Events: {positive_count} ({positive_count/len(matching_events)*100:.1f}%)")
    print(f"⚠️  Negative Impact Events: {negative_count} ({negative_count/len(matching_events)*100:.1f}%)")
    print(f"➖ Neutral Impact Events: {neutral_count} ({neutral_count/len(matching_events)*100:.1f}%)")
    print(f"📈 Total Events: {len(matching_events)}")

    # Recommendation
    print(f"\n{'='*80}")
    print("💡 RECOMMENDATION")
    print(f"{'='*80}")

    positive_ratio = positive_count / len(matching_events)
    negative_ratio = negative_count / len(matching_events)

    if positive_ratio > 0.5:
        print("🟢 EXCELLENT DAY for your campaign!")
        print("   Many events will attract your target audience.")
    elif positive_ratio > 0.3 and negative_ratio < 0.3:
        print("🟡 GOOD DAY for your campaign.")
        print("   Decent event alignment with manageable competition.")
    elif negative_ratio > 0.5:
        print("🔴 CHALLENGING DAY for your campaign.")
        print("   Consider alternative dates or adjust messaging.")
    else:
        print("🟡 MODERATE DAY for your campaign.")
        print("   Standard conditions, focus on differentiation.")

    print(f"{'='*80}\n")


# ========== INTERACTIVE CAMPAIGN PLANNER ==========

print("\n" + "="*80)
print("🎯 CAMPAIGN IMPACT ANALYZER")
print("="*80)
print("\n✅ TESTED INPUT COMBINATIONS:")
print("   📅 Date: 2025-01-27  |  📍 City: Cormeilles-en-Parisis  |  🎯 Sector: entertainment")
print("   📅 Date: 2025-03-10  |  📍 City: Paris  |  🎯 Sector: food")
print("   📅 Date: 2025-05-30  |  📍 City: Fontainebleau  |  🎯 Sector: tourism")
print("   📅 Date: 2025-01-01  |  📍 City: Drancy  |  🎯 Sector: retail")
print("\n📋 Available sectors:")
print("   food, restaurant, retail, fitness, entertainment, healthcare, tourism, education")
print("="*80 + "\n")

# Get user input
target_date = input("📅 Enter campaign date (YYYY-MM-DD): ").strip()
target_city = input("📍 Enter city name: ").strip()
campaign_sector = input("🎯 Enter your business sector: ").strip()

# Validate date format
try:
    datetime.strptime(target_date, '%Y-%m-%d')
except ValueError:
    print("\n❌ Invalid date format. Please use YYYY-MM-DD (e.g., 2025-03-15)")
    exit()

# Validate sector
if campaign_sector.lower() not in IMPACT_RULES:
    print(f"\n⚠️  Warning: '{campaign_sector}' not in predefined sectors.")
    print("   Analysis will use general impact assessment.")

# Run analysis
analyze_campaign(target_date, target_city, campaign_sector)
# Out:
# ================================================================================
# 🎯 CAMPAIGN IMPACT ANALYZER
# ================================================================================
#
# ✅ TESTED INPUT COMBINATIONS:
#    📅 Date: 2025-01-27  |  📍 City: Cormeilles-en-Parisis  |  🎯 Sector: entertainment
#    📅 Date: 2025-03-10  |  📍 City: Paris  |  🎯 Sector: food
#    📅 Date: 2025-05-30  |  📍 City: Fontainebleau  |  🎯 Sector: tourism
#    📅 Date: 2025-01-01  |  📍 City: Drancy  |  🎯 Sector: retail
#
# 📋 Available sectors:
#    food, restaurant, retail, fitness, entertainment, healthcare, tourism, education
# ================================================================================
#
# 📅 Enter campaign date (YYYY-MM-DD): 2025-12-25
# 📍 Enter city name: Paris
# 🎯 Enter your business sector: food
#
# ================================================================================
# 📋 CAMPAIGN IMPACT ANALYSIS
# ================================================================================
# 📅 Date: 2025-12-25
# 📍 City: Paris
# 🎯 Sector: FOOD
# ================================================================================
#
# ⏳ Fetching event data...
# 📦 Processing 438 events...
#    Processed 100/438 events...
#    Processed 200/438 events...
#    Processed 300/438 events...
#    Processed 400/438 events...
#
# ✅ Found 21 events matching your criteria
#
# +----------+----------------------------------------+----------------+-------------+--------------------------+
# |   Sr.No. | Event Name                             | Industry       | Impact      | Reason                   |
# +==========+========================================+================+=============+==========================+
# |        1 | Marché couvert Saint-Germain           | Retail         | ➖ Neutral  | Minimal direct impact    |
# +----------+----------------------------------------+----------------+-------------+--------------------------+
# |        2 | Marché couvert des Ternes              | Retail         | ➖ Neutral  | Minimal direct impact    |
# +----------+----------------------------------------+----------------+-------------+--------------------------+
# |        3 | Les Dimanches Plaisirs à l’Hippodrome  | Sports/Fitness | ⚠️ Negative | Competing or conflicting |
# |          | Pa...                                  |                |             |                          |
# +----------+----------------------------------------+----------------+-------------+--------------------------+
# |        4 | Éternelle Notre-Dame                   | Arts/Culture   | ➖ Neutral  | Minimal direct impact    |
# +----------+----------------------------------------+----------------+-------------+--------------------------+
# |        5 | Nouvel accrochage à Dalí Paris         | General        | ➖ Neutral  | Minimal direct impact    |
# +----------+----------------------------------------+----------------+-------------+--------------------------+
# |        6 | Marché couvert de Passy                | Retail         | ➖ Neutral  | Minimal direct impact    |
# +----------+----------------------------------------+----------------+-------------+--------------------------+
# |        7 | Marché de Noël Paris Notre-Dame        | Sports/Fitness | ⚠️ Negative | Competing or conflicting |
# +----------+----------------------------------------+----------------+-------------+--------------------------+
# |        8 | FrenchTrotters                         | General        | ➖ Neutral  | Minimal direct impact    |
# +----------+----------------------------------------+----------------+-------------+--------------------------+
# |        9 | Visites autonomes accessibles à tous - | General        | ➖ Neutral  | Minimal direct impact    |
# |          | M...                                   |                |             |                          |
# +----------+----------------------------------------+----------------+-------------+--------------------------+
# |       10 | La meilleure baguette de Paris         | Retail         | ➖ Neutral  | Minimal direct impact    |
# +----------+----------------------------------------+----------------+-------------+--------------------------+
# |       11 | Election du plus beau jardin           | Arts/Culture   | ➖ Neutral  | Minimal direct impact    |
# +----------+----------------------------------------+----------------+-------------+--------------------------+
# |       12 | Marché couvert La Chapelle             | Retail         | ➖ Neutral  | Minimal direct impact    |
# +----------+----------------------------------------+----------------+-------------+--------------------------+
# |       13 | Destination Lune : un voyage immersif  | Arts/Culture   | ➖ Neutral  | Minimal direct impact    |
# |          | av...                                  |                |             |                          |
# +----------+----------------------------------------+----------------+-------------+--------------------------+
# |       14 | How to become Parisian in one hour ?   | Sports/Fitness | ⚠️ Negative | Competing or conflicting |
# +----------+----------------------------------------+----------------+-------------+--------------------------+
# |       15 | Dîner-revue Moulin Rouge               | General        | ➖ Neutral  | Minimal direct impact    |
# +----------+----------------------------------------+----------------+-------------+--------------------------+
# |       16 | Marché couvert Saint-Didier            | Retail         | ➖ Neutral  | Minimal direct impact    |
# +----------+----------------------------------------+----------------+-------------+--------------------------+
# |       17 | Visite de la Maison de la Radio        | Arts/Culture   | ➖ Neutral  | Minimal direct impact    |
# +----------+----------------------------------------+----------------+-------------+--------------------------+
# |       18 | L'enfance de l'Art                     | Arts/Culture   | ➖ Neutral  | Minimal direct impact    |
# +----------+----------------------------------------+----------------+-------------+--------------------------+
# |       19 | Aura Invalides                         | Entertainment  | ✅ Positive | Attracts relevant        |
# |          |                                        |                |             | audience                 |
# +----------+----------------------------------------+----------------+-------------+--------------------------+
# |       20 | Marché couvert Saint-Quentin           | Retail         | ➖ Neutral  | Minimal direct impact    |
# +----------+----------------------------------------+----------------+-------------+--------------------------+
# |       21 | Theatre in Paris                       | Entertainment  | ✅ Positive | Attracts relevant        |
# |          |                                        |                |             | audience                 |
# +----------+----------------------------------------+----------------+-------------+--------------------------+
#
# ================================================================================
# 📊 IMPACT SUMMARY
# ================================================================================
# ✅ Positive Impact Events: 2 (9.5%)
# ⚠️  Negative Impact Events: 3 (14.3%)
# ➖ Neutral Impact Events: 16 (76.2%)
# 📈 Total Events: 21
#
# ================================================================================
# 💡 RECOMMENDATION
# ================================================================================
# 🟡 MODERATE DAY for your campaign.
#    Standard conditions, focus on differentiation.
# ================================================================================
